# %%
import pandas as pd
import seaborn as sns

df = sns.load_dataset("diamonds")  # used for price prediction practice
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3265/1472378890.py in <cell line: 0>()
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (53940, 10)

# %%
df.info
# Out:
# <bound method DataFrame.info of        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# ...

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
df = pd.get_dummies(df, drop_first=True)
df.head()
# Out:
#    carat  depth  table  price     x     y     z  cut_Premium  cut_Very Good  \
# 0   0.23   61.5   55.0    326  3.95  3.98  2.43        False          False
# 1   0.21   59.8   61.0    326  3.89  3.84  2.31         True          False
# 2   0.23   56.9   65.0    327  4.05  4.07  2.31        False          False
# 3   0.29   62.4   58.0    334  4.20  4.23  2.63         True          False
# 4   0.31   63.3   58.0    335  4.34  4.35  2.75        False          False
#
#    cut_Good  ...  color_H  color_I  color_J  clarity_VVS1  clarity_VVS2  \
# 0     False  ...    False    False    False         False         False
# 1     False  ...    False    False    False         False         False
# 2      True  ...    False    False    False         False         False
# 3     False  ...    False     True    False         False         False
# 4      True  ...    False    False     True         False         False
#
#    clarity_VS1  clarity_VS2  clarity_SI1  clarity_SI2  clarity_I1
# ...

# %%
X = df.drop("price", axis=1)
y = df["price"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score

r2_score(y_test, y_pred)
# Out:
# 0.9208165069533725

# %%
from sklearn.metrics import r2_score

score = r2_score(y_test, y_pred)
print("Model Accuracy (R2 Score):", score)
# Out:
# Model Accuracy (R2 Score): 0.9208165069533725

# %%
import matplotlib.pyplot as plt

plt.scatter(y_test, y_pred)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Actual vs Predicted Prices")
plt.show()

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)
# Out:
# Mean Absolute Error: 737.304016741906

# %% [markdown]
# ## 📌 Final Conclusion
#
# A Linear Regression model was built to predict diamond prices based on various features.
#
# The model was trained on 80% of the dataset and tested on 20%.
#
# The R² score indicates the model’s performance in predicting prices.
#
# The Actual vs Predicted plot shows how closely the model predictions match real values.
#
# Overall, this project demonstrates basic machine learning workflow including data preprocessing, model training, prediction, and evaluation.
