# %% [markdown]
# # 📊 Retail Sales Exploratory Data Analysis (EDA)
#
# ## Objective
#
# The objective of this project is to analyze retail sales data, identify sales trends, understand customer purchasing behavior, evaluate product performance, and generate business insights using Exploratory Data Analysis (EDA).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("retail_sales_dataset.csv")

# %%
df.head()
# Out:
#    Transaction ID        Date Customer ID  Gender  Age Product Category  \
# 0               1  2023-11-24     CUST001    Male   34           Beauty
# 1               2  2023-02-27     CUST002  Female   26         Clothing
# 2               3  2023-01-13     CUST003    Male   50      Electronics
# 3               4  2023-05-21     CUST004    Male   37         Clothing
# 4               5  2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    1000 non-null   int64
#  1   Date              1000 non-null   object
#  2   Customer ID       1000 non-null   object
#  3   Gender            1000 non-null   object
#  4   Age               1000 non-null   int64
#  5   Product Category  1000 non-null   object
#  6   Quantity          1000 non-null   int64
#  7   Price per Unit    1000 non-null   int64
#  8   Total Amount      1000 non-null   int64
# dtypes: int64(5), object(4)
# memory usage: 70.4+ KB

# %%
df.describe()
# Out:
#        Transaction ID         Age     Quantity  Price per Unit  Total Amount
# count     1000.000000  1000.00000  1000.000000     1000.000000   1000.000000
# mean       500.500000    41.39200     2.514000      179.890000    456.000000
# std        288.819436    13.68143     1.132734      189.681356    559.997632
# min          1.000000    18.00000     1.000000       25.000000     25.000000
# 25%        250.750000    29.00000     1.000000       30.000000     60.000000
# 50%        500.500000    42.00000     3.000000       50.000000    135.000000
# 75%        750.250000    53.00000     4.000000      300.000000    900.000000
# max       1000.000000    64.00000     4.000000      500.000000   2000.000000

# %%
df.isnull().sum()
# Out:
# Transaction ID      0
# Date                0
# Customer ID         0
# Gender              0
# Age                 0
# Product Category    0
# Quantity            0
# Price per Unit      0
# Total Amount        0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Transaction ID', 'Date', 'Customer ID', 'Gender', 'Age',
#        'Product Category', 'Quantity', 'Price per Unit', 'Total Amount'],
#       dtype='object')

# %%
df['Date'] = pd.to_datetime(df['Date'])

df.head()
# Out:
#    Transaction ID       Date Customer ID  Gender  Age Product Category  \
# 0               1 2023-11-24     CUST001    Male   34           Beauty
# 1               2 2023-02-27     CUST002  Female   26         Clothing
# 2               3 2023-01-13     CUST003    Male   50      Electronics
# 3               4 2023-05-21     CUST004    Male   37         Clothing
# 4               5 2023-05-06     CUST005    Male   30           Beauty
#
#    Quantity  Price per Unit  Total Amount
# 0         3              50           150
# 1         2             500          1000
# 2         1              30            30
# 3         1             500           500
# 4         2              50           100

# %% [markdown]
# ## Monthly Sales Analysis

# %%
df['Month'] = df['Date'].dt.month_name()

monthly_sales = df.groupby('Month')['Total Amount'].sum()

print(monthly_sales)
# Out:
# Month
# April        33870
# August       36960
# December     44690
# February     44060
# January      36980
# July         35465
# June         36715
# March        28990
# May          53150
# November     34920
# October      46580
# September    23620
# Name: Total Amount, dtype: int64

# %% [markdown]
# ## Monthly Sales Trend

# %%
plt.figure(figsize=(10,5))

monthly_sales.plot(kind='bar')

plt.title("Monthly Sales")

plt.xlabel("Month")

plt.ylabel("Total Sales")

plt.show()

# %% [markdown]
# ## Product Category Analysis

# %%
category_sales = df.groupby('Product Category')['Total Amount'].sum()

print(category_sales)
# Out:
# Product Category
# Beauty         143515
# Clothing       155580
# Electronics    156905
# Name: Total Amount, dtype: int64

# %% [markdown]
# ## Sales by Product Category

# %%
plt.figure(figsize=(8,5))

category_sales.plot(kind='bar')

plt.title("Sales by Product Category")

plt.xlabel("Category")

plt.ylabel("Total Sales")

plt.show()

# %% [markdown]
# ## Gender-wise Sales Analysis

# %%
gender_sales = df.groupby('Gender')['Total Amount'].sum()

print(gender_sales)
# Out:
# Gender
# Female    232840
# Male      223160
# Name: Total Amount, dtype: int64

# %%
plt.figure(figsize=(6,5))

gender_sales.plot(kind='bar')

plt.title("Sales by Gender")

plt.xlabel("Gender")

plt.ylabel("Total Sales")

plt.show()

# %% [markdown]
# ## Age Distribution

# %%
plt.figure(figsize=(8,5))

sns.histplot(df['Age'], bins=10, kde=True)

plt.title("Customer Age Distribution")

plt.xlabel("Age")

plt.ylabel("Number of Customers")

plt.show()

# %% [markdown]
# ## Correlation Heatmap

# %%
plt.figure(figsize=(8,6))

numeric_df = df.select_dtypes(include=['int64', 'float64'])

sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')

plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# ## Top 10 Highest Sales Transactions

# %%
top_sales = df.sort_values(by='Total Amount', ascending=False)

top_sales.head(10)

# %% [markdown]
# # Business Insights
#
# - Monthly sales analysis helps identify peak sales periods.
# - Product category analysis highlights the best-performing categories.
# - Gender-wise analysis provides customer purchasing trends.
# - Age distribution helps understand the target customer group.
# - Correlation analysis shows relationships between numerical variables.
# - These insights can support inventory planning, marketing strategies, and sales forecasting.

# %% [markdown]
# # Conclusion
#
# This project performed Exploratory Data Analysis (EDA) on a Retail Sales dataset using Python.
#
# The dataset was cleaned, explored, and analyzed using descriptive statistics and visualizations. Monthly sales, product categories, customer demographics, and sales trends were examined to identify meaningful business insights.
#
# The analysis demonstrates how EDA can help businesses understand customer behavior, optimize product strategies, and support data-driven decision-making.
